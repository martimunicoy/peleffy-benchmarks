# %% [markdown]
# # Geometry Benchmark

# %% [markdown]
# ## SMIRNOFF Coverage Set 1

# %% [markdown]
# ### Retrieve QM optimized structures

# %%
from getter import QCPortal
from peleffy.topology import Molecule

# %%
qc_portal = QCPortal(n_proc=4)

# %%
qc_portal.get_structures('SMIRNOFF Coverage Set 1', output_path='QM')
# Out:
# ...
# 100%|██████████| 1132/1132 [06:59<00:00,  2.70it/s]

# %% [markdown]
# ### Retrieve data

# %%
data = qc_portal.get_data('SMIRNOFF Coverage Set 1')
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 12840.28it/s]

# %%
minimizer = Minimizer()
for name, attributes in data.items():
    molecule = Molecule
    print(name, attributes['canonical_isomeric_explicit_hydrogen_mapped_smiles'])
# Out:
# coc(o)oc-0 [H:7][C:1]([H:8])([H:9])[O:5][C:3]([H:13])([O:4][H:14])[O:6][C:2]([H:10])([H:11])[H:12]
# c[s-]-0 [H:3][C:1]([H:4])([H:5])[S-:2]
# cs-0 [H:3][C:1]([H:4])([H:5])[S:2][H:6]
# co-0 [H:3][C:1]([H:4])([H:5])[O:2][H:6]
# cco-0 [H:4][C:1]([H:5])([H:6])[C:2]([H:7])([H:8])[O:3][H:9]
# c#cc1ccccc1-0 [H:9][C:1]#[C:2][c:8]1[c:6]([c:4]([c:3]([c:5]([c:7]1[H:14])[H:12])[H:10])[H:11])[H:13]
# c#cc1ccccc1-1 [H:9][C:1]#[C:2][c:8]1[c:6]([c:4]([c:3]([c:5]([c:7]1[H:14])[H:12])[H:10])[H:11])[H:13]
# c(=[nh2+])n-0 [H:4][C:1](=[N+:3]([H:7])[H:8])[N:2]([H:5])[H:6]
# [h]/n=c/n-0 [H:4]/[C:1](=[N:2]\[H:5])/[N:3]([H:6])[H:7]
# [h]/n=c\n-0 [H:4]/[C:1](=[N:2]/[H:5])/[N:3]([H:6])[H:7]
# c[s@](=[n-])(=o)nc1cc1-0 [H:9][C:1]1([C:2]([C:3]1([H:13])[N:6]([H:17])[S@@:8](=[N-:5])(=[O:7])[C:4]([H:14])([H:15])[H:16])([H:11])[H:12])[H:10]
# c[s@](=[n-])(=o)nc1cc1-1 [H:9][C:1]1([C:2]([C:3]1([H:13])[N:6]([H:17])[S@@:8](=[N-:5])(=[O:7])[C:4]([H:14])([H:15])[H:16])([H:11])[H:12])[H:10]
# ...
