# %%
import os
import argparse 
import pandas as pd
from offpele.topology import Molecule, RotamerLibrary
from offpele.template import Impact
from offpele.solvent import OBC2
from offpele.main import handle_output_paths

#Local imports
import DiffEnergies as DiffEnergies
from solventhandler import SolventBenchmark
from methods import method_OFF, method_OPLS, method_OFFOPLS

# %%
# Define the method
method1 = list(('OFF', 'gasteiger', 'OBC', None, None))

# Initialize the solvent benchmark
benchmark = SolventBenchmark(method = method1)
# Run the benchmark
energies, differences, experimental_values = benchmark.run()
# Save a file with the output
benchmark.save_output(out_folder = 'OFF_out1', energies = energies)
#Plot the results
benmark.plot_results(energies = energies, differences = differences, experimental_values = experimental_values)

# %%
# Define the method
method2 = list(('OFF', 'am1bcc', 'OBC', None, None))

# Initialize the solvent benchmark with a method
benchmark = SolventBenchmark(method = method2)
benchmark.plot_results(file = '/home/lauramalo/tests/FreeSolv/Scripts_Laura/OFF_out2/results.txt')
